# %%
from minisom import MiniSom
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,4.8
import math
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import zscore
import somoclu
#import Orange
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
filedata= 'D:/Development/mestrado/uma/dataset/db_fm_training.csv'
df = pd.read_csv(filedata, engine='python', sep=';')
df.head()
# Out:
#    Retainability   HOSR    RSRP    RSRQ    SINR  Throughput  Distance
# 0          0.853  0.609 -66.728 -20.042  10.836     148.692     0.713
# 1          0.909  0.800 -61.816 -19.071  15.236     205.652     0.601
# 2          0.963  0.818 -61.778 -18.862  16.395     251.339     0.587
# 3          0.940  0.889 -63.843 -19.436  14.816     232.213     0.586
# 4          0.952  0.900 -61.796 -19.403  14.402     191.574     0.629

# %%
#df_zscore = df.apply(zscore)
#df_zscore
dataset = df.values
dataset = dataset.astype('float32')
dataset
# Out:
# array([[   0.85299999,    0.60900003,  -66.72799683, ...,   10.83600044,
#          148.69200134,    0.713     ],
#        [   0.90899998,    0.80000001,  -61.81600189, ...,   15.23600006,
#          205.6519928 ,    0.60100001],
#        [   0.963     ,    0.81800002,  -61.77799988, ...,   16.39500046,
#          251.33900452,    0.58700001],
#        ...,
#        [   0.99400002,    0.98400003,  -72.59700012, ...,   14.91699982,
#           99.12799835,    0.92500001],
#        [   0.99400002,    0.98000002,  -67.20999908, ...,   15.83199978,
#          129.54699707,    0.92000002],
#        [   0.995     ,    0.98100001,  -69.38999939, ...,   15.34500027,
#          121.27799988,    0.93099999]], dtype=float32)

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)
dataset
# Out:
# array([[ 0.0199995 ,  0.37037039,  0.72958207, ...,  0.47666061,
#          0.47903123,  0.17731959],
#        [ 0.39333296,  0.67793882,  0.99792385, ...,  0.84473825,
#          0.76812267,  0.06185567],
#        [ 0.75333309,  0.70692432,  1.        , ...,  0.94169331,
#          1.        ,  0.04742271],
#        ...,
#        [ 0.96000004,  0.97423518,  0.40895915, ...,  0.81805265,
#          0.22747687,  0.39587629],
#        [ 0.96000004,  0.96779394,  0.70325041, ...,  0.89459598,
#          0.38186374,  0.39072162],
#        [ 0.9666667 ,  0.96940422,  0.58415723, ...,  0.85385656,
#          0.33989576,  0.40206182]], dtype=float32)

# %%
#n_rows, n_columns = 100, 160
n_rows, n_columns = 10, 10
#som = somoclu.Somoclu(n_columns, n_rows, compactsupport=False)
som = somoclu.Somoclu(n_columns, n_rows, compactsupport=False,initialization="pca",gridtype='rectangular',neighborhood='gaussian')
# %time som.train(dataset,epochs=1000, radius0=10, radiusN=2, radiuscooling='linear', scale0=0.1, scaleN=0.01, scalecooling='linear')
# Out:
# Wall time: 3.84 s

# %%
som.view_component_planes()
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Anaconda2\\envs\\py36\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
som.view_umatrix(bestmatches=True)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Anaconda2\\envs\\py36\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#som.view_umatrix(bestmatches=True, bestmatchcolors=a, labels=labels)
som.view_activation_map(data_index=549,bestmatches=True)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Anaconda2\\envs\\py36\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
#som.view_umatrix(bestmatches=True, bestmatchcolors=a, labels=labels)
som.view_umatrix(bestmatches=True)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Anaconda2\\envs\\py36\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# %time som.train(dataset,epochs=20000, radius0=1, radiusN=0, radiuscooling='linear', scale0=0.01, scaleN=0.01, scalecooling='linear')
# Out:
# Wall time: 1min 16s

# %%
#som.view_umatrix(bestmatches=True, bestmatchcolors=a, labels=labels)
#som.view_umatrix(bestmatches=True, bestmatchcolors=a, labels=a)
som.view_activation_map(bestmatches=True)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-93-22e6537e5a96> in <module>()
#       1 #som.view_umatrix(bestmatches=True, bestmatchcolors=a, labels=labels)
#       2 #som.view_umatrix(bestmatches=True, bestmatchcolors=a, labels=a)
# ----> 3 som.view_activation_map(bestmatches=True)
#
# C:\Anaconda2\envs\py36\lib\site-packages\somoclu\train.py in view_activation_map(self, data_vector, data_index, activation_map, figsize, colormap, colorbar, bestmatches, bestmatchcolors, labels, zoom, filename)
#     354         """
#     355         if data_vector is None and data_index is None:
# --> 356             raise Exception("Either specify a vector to see its activation "
#     357                             "or give an index of the training data instances")
#     358         if data_vector is not None and data_index is not None:
#
# ...

# %%
cluster = som.cluster()

# %%
#som.view_umatrix(bestmatches=True, bestmatchcolors=a, labels=a)
som.view_activation_map()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f1f6386a463c> in <module>()
#       1 #som.view_umatrix(bestmatches=True, bestmatchcolors=a, labels=a)
# ----> 2 som.view_activation_map()
#
# NameError: name 'som' is not defined

# %%
filedata= 'D:/Development/mestrado/uma/dataset/db_fm_training2.csv'
df2 = pd.read_csv(filedata, engine='python', sep=';')
df2.head()
#df2
# Out:
#    Retainability   HOSR    RSRP    RSRQ    SINR  Throughput  Distance  Class
# 0          0.853  0.609 -66.728 -20.042  10.836     148.692     0.713      1
# 1          0.909  0.800 -61.816 -19.071  15.236     205.652     0.601      1
# 2          0.963  0.818 -61.778 -18.862  16.395     251.339     0.587      1
# 3          0.940  0.889 -63.843 -19.436  14.816     232.213     0.586      1
# 4          0.952  0.900 -61.796 -19.403  14.402     191.574     0.629      1

# %%
a = df2['Class'].tolist()
labels = range(len(df))

# %%
BMU.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-a6bb65bbe322> in <module>()
# ----> 1 BMU.shape()
#
# NameError: name 'BMU' is not defined

# %%
W = som.codebook.reshape((som.codebook.shape[0] * som.codebook.shape[1], som.codebook.shape[2]))
X =
# Out:
# 0.97866464

# %%
som.get_bmus(som.get_surface_state(dataset)).shape
# Out:
# (550, 2)

# %% [markdown]
# For a new data 'data'
#  - reshapes the (10,12,3) code book to (120,3)
#  - store data in X
#  - Calculate the distance between the data and the codebooks
#  - create a BMU

# %%
W = som.codebook.reshape((som.codebook.shape[0] * som.codebook.shape[1], som.codebook.shape[2]))
X = data

D = -2*np.dot(W, X.T) + (W**2).sum(1)[:, None] + (X**2).sum(1)[:, None].T
BMU = (D==D.min(0)[None,:]).astype("float32").T
NBMU =  BMU.reshape((X.shape[0], som.codebook.shape[0], som.codebook.shape[1]))
new_bmus = np.vstack(NBMU.nonzero()[1:][::-1]).T
